# %% [markdown]
# <a href="https://colab.research.google.com/github/rosiekeogh07/UCDPA_RosieKeogh/blob/main/Explore_IAA_Register_March_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Data**
#
# *   The project should use a real-world dataset and include a reference to the
# source in the report
#
#
# ---
#
# ***IAA Monthly Register 31 March 2022***
#
# **Who are the IAA?**
# The IAA are the Irish Aviation Authority. The Irish Aviation Authority promotes and regulates the safety of aviation in Ireland. The Irish Aviation Authority is responsible for the registration of civil aircraft in Ireland. We are going to look at the most recent Register listing. The IAA Register is updated monthly.
#
# [IAA CURRENT AIRCRAFT REGISTER AND MONTHLY CHANGES](https://www.iaa.ie/commercial-aviation/aircraft-registration-2/latest-register-and-monthly-changes-1)

# %% [markdown]
# ![Irish-Aviation-Authority-IAA.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **2. Importing**
#
#
# *   Import data from a flat file (.csv, .xls, xlsx, .txt, etc.)
# *   Retrieve data using online SQL, APIs, or web scraping
#
#
#
#
# ---

# %%
import numpy as np # linear algebra

# %%
import pandas as pd # data processing

# %%
import matplotlib.pyplot as plt # visualisation

# %%
import seaborn as sns # visualisation

# %%
#Import data from a flat file (.csv, .xls, xlsx, .txt, etc.). Here I am using an Excel file (.xlsx)
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39d5ea06-692d-4f5d-a6fe-088dedc3c6ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39d5ea06-692d-4f5d-a6fe-088dedc3c6ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 31-march-2022 (1).xlsx to 31-march-2022 (1).xlsx

# %% [markdown]
# ## **3. Preperation**
#
#
# *   Create pandas DataFrame
# *   Sorting, indexing, grouping
# *   Drop duplicates, replace missing values
# *   Merge DataFrames
#
#
# ---

# %%
# read file
df = pd.read_excel("31-march-2022 (1).xlsx")
df
# Out:
#      Registration Mark             Aircraft producer  \
# 0               EI-ABI  DE HAVILLAND AIRCRAFT CO LTD
# 1               EI-ABS       BOEING AIRPLANE COMPANY
# 2               EI-AEE           AUSTER AIRCRAFT LTD
# 3               EI-AEF       CESSNA AIRCRAFT COMPANY
# 4               EI-AEH         LUSCOMBE AIRCRAFT LTD
# ...                ...                           ...
# 1247           EJ-REVA    BEECH AIRCRAFT CORPORATION
# 1248           EJ-ROXY                BOMBARDIER INC
# 1249           EJ-VAIS      PILATUS AIRCRAFT LIMITED
# 1250               NaN                           NaN
# 1251             Total                          1250
#
#                  Aircraft Model        Category Registration date  MTOW (KGs)  \
# 0                   DH84 DRAGON  LAND AEROPLANE        12/08/1985      1792.0
# 1                         B75N1  LAND AEROPLANE        17/10/2019      1338.0
# 2                    AUSTER 5J1  LAND AEROPLANE        22/12/2009       839.0
# ...

# %% [markdown]
# There are **1252 rows** with **14 columns**. Each row shows a unique Aircraft Registration number which is specific to that Aircraft

# %%
# return first 5 rows of the DataFrame plus the header
df.head()
# Out:
#   Registration Mark             Aircraft producer Aircraft Model  \
# 0            EI-ABI  DE HAVILLAND AIRCRAFT CO LTD    DH84 DRAGON
# 1            EI-ABS       BOEING AIRPLANE COMPANY          B75N1
# 2            EI-AEE           AUSTER AIRCRAFT LTD     AUSTER 5J1
# 3            EI-AEF       CESSNA AIRCRAFT COMPANY     CESSNA 120
# 4            EI-AEH         LUSCOMBE AIRCRAFT LTD    LUSCOMBE 8F
#
#          Category Registration date  MTOW (KGs)  Year of Manufacture  \
# 0  LAND AEROPLANE        12/08/1985      1792.0               1936.0
# 1  LAND AEROPLANE        17/10/2019      1338.0               1941.0
# 2  LAND AEROPLANE        22/12/2009       839.0               1946.0
# 3  LAND AEROPLANE        16/03/2011       658.0               1947.0
# 4  LAND AEROPLANE        07/01/2014       635.0               1945.0
#
#   Aircraft Serial Number  Mode S             Engine Manufacturer  \
# 0                   6105  4CA368                       BLACKBURN
# ...

# %%
# Display names of columns, the datatypes they contain and whether they contain any missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Registration Mark       1251 non-null   object
#  1   Aircraft producer       1251 non-null   object
#  2   Aircraft Model          1250 non-null   object
#  3   Category                1250 non-null   object
#  4   Registration date       1250 non-null   object
#  5   MTOW (KGs)              1250 non-null   float64
#  6   Year of Manufacture     1250 non-null   float64
#  7   Aircraft Serial Number  1250 non-null   object
#  8   Mode S                  1020 non-null   object
#  9   Engine Manufacturer     1186 non-null   object
#  10  Engine Model            1191 non-null   object
#  11  No. of Engines          1250 non-null   float64
#  12  Registered Owner        1250 non-null   object
#  13  Address                 1250 non-null   object
# ...

# %%
# tuple containing number of rows followed by number of columns (attribute not a method)
df.shape
# Out:
# (1252, 14)

# %% [markdown]
# Confirming - There are **1252 rows** with **14 columns**

# %%
# Registration Mark is now the Index
df_ind = df.set_index("Registration Mark")
df_ind
# Out:
#                               Aircraft producer             Aircraft Model  \
# Registration Mark
# EI-ABI             DE HAVILLAND AIRCRAFT CO LTD                DH84 DRAGON
# EI-ABS                  BOEING AIRPLANE COMPANY                      B75N1
# EI-AEE                      AUSTER AIRCRAFT LTD                 AUSTER 5J1
# EI-AEF                  CESSNA AIRCRAFT COMPANY                 CESSNA 120
# EI-AEH                    LUSCOMBE AIRCRAFT LTD                LUSCOMBE 8F
# ...                                         ...                        ...
# EJ-REVA              BEECH AIRCRAFT CORPORATION               HAWKER 800XP
# EJ-ROXY                          BOMBARDIER INC  CL-600-2B16 (604 VARIANT)
# EJ-VAIS                PILATUS AIRCRAFT LIMITED          PILATUS PC-12/47E
# NaN                                         NaN                        NaN
# Total                                      1250                        NaN
#
# ...

# %%
#Undo what we just done. It looks better with the Index numbers
df_ind.reset_index() # It is now back to how it was
# Out:
#      Registration Mark             Aircraft producer  \
# 0               EI-ABI  DE HAVILLAND AIRCRAFT CO LTD
# 1               EI-ABS       BOEING AIRPLANE COMPANY
# 2               EI-AEE           AUSTER AIRCRAFT LTD
# 3               EI-AEF       CESSNA AIRCRAFT COMPANY
# 4               EI-AEH         LUSCOMBE AIRCRAFT LTD
# ...                ...                           ...
# 1247           EJ-REVA    BEECH AIRCRAFT CORPORATION
# 1248           EJ-ROXY                BOMBARDIER INC
# 1249           EJ-VAIS      PILATUS AIRCRAFT LIMITED
# 1250               NaN                           NaN
# 1251             Total                          1250
#
#                  Aircraft Model        Category Registration date  MTOW (KGs)  \
# 0                   DH84 DRAGON  LAND AEROPLANE        12/08/1985      1792.0
# 1                         B75N1  LAND AEROPLANE        17/10/2019      1338.0
# 2                    AUSTER 5J1  LAND AEROPLANE        22/12/2009       839.0
# ...

# %%
# summary statistics for numerical columns / quick overview of numerical values
df.describe()
# Out:
#           MTOW (KGs)  Year of Manufacture  No. of Engines
# count    1250.000000          1250.000000     1250.000000
# mean    49311.036800          2000.378400        1.531200
# std     69126.903258            18.071383        0.622042
# min        95.000000          1935.000000        0.000000
# 25%       600.000000          1998.000000        1.000000
# 50%     37995.000000          2006.000000        2.000000
# 75%     68038.000000          2011.000000        2.000000
# max    396893.000000          2022.000000        4.000000

# %%
#column names
df.columns
# Out:
# Index(['Registration Mark', 'Aircraft producer', 'Aircraft Model', 'Category',
#        'Registration date', 'MTOW (KGs)', 'Year of Manufacture',
#        'Aircraft Serial Number', 'Mode S', 'Engine Manufacturer',
#        'Engine Model', 'No. of Engines', 'Registered Owner', 'Address'],
#       dtype='object')

# %%
# row numbers
df.index
# Out:
# RangeIndex(start=0, stop=1252, step=1)

# %%
# values attribute (data values in 2 dimensional NumPy array)
df.values
# Out:
# array([['EI-ABI', 'DE HAVILLAND AIRCRAFT CO LTD', 'DH84 DRAGON', ...,
#         2.0, 'AER LINGUS CHARITABLE FOUNDATION',
#         'DUBLIN AIRPORT, CO. DUBLIN, '],
#        ['EI-ABS', 'BOEING AIRPLANE COMPANY', 'B75N1', ..., 1.0,
#         'BENNETT SEAN',
#         '120 CHURCHTOWN ROAD LOWER, CHURCHTOWN, DUBLIN, 14, IRELAND'],
#        ['EI-AEE', 'AUSTER AIRCRAFT LTD', 'AUSTER 5J1', ..., 1.0,
#         "O'SULLIVAN, OWEN EUGENE PATRICK\nO'SULLIVAN ARNOULD, NICOLE",
#         'GLENARD, CROSTHWAITE PARK, DUN LAOGHAIRE, CO DUBLIN, IRELAND\nGLENARD, CROSTHWAITE PARK, DUN LAOGHAIRE, CO.DUBLIN, IRELAND'],
#        ...,
#        ['EJ-VAIS', 'PILATUS AIRCRAFT LIMITED', 'PILATUS PC-12/47E', ...,
#         1.0, 'CAFICO TRUST COMPANY LIMITED',
#         'PALMERSTON HOUSE, DENZILLE LANE, DUBLIN 2, '],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ['Total', 1250, nan, ..., nan, nan, nan]], dtype=object)

# %%
# print one column only (Category column)
df["Category"]
# Out:
# 0       LAND AEROPLANE
# 1       LAND AEROPLANE
# 2       LAND AEROPLANE
# 3       LAND AEROPLANE
# 4       LAND AEROPLANE
#              ...
# 1247    LAND AEROPLANE
# 1248    LAND AEROPLANE
# 1249    LAND AEROPLANE
# 1250               NaN
# 1251               NaN
# Name: Category, Length: 1252, dtype: object

# %%
# print one column only (Registered Owner column)
df["Registered Owner"]
# Out:
# 0                        AER LINGUS CHARITABLE FOUNDATION
# 1                                            BENNETT SEAN
# 2       O'SULLIVAN, OWEN EUGENE PATRICK\nO'SULLIVAN AR...
# 3                                          HALLIGAN JAMES
# 4                                             KELLY DAVID
#                               ...
# 1247                             GAIN JET IRELAND LIMITED
# 1248                                ACASS IRELAND LIMITED
# 1249                         CAFICO TRUST COMPANY LIMITED
# 1250                                                  NaN
# 1251                                                  NaN
# Name: Registered Owner, Length: 1252, dtype: object

# %%
# Subsetting multiple columns #Use 2 square brackets. The two brackets are performing different tasks. The outer square brackets are responsible for subsetting the DataFrame, the inner square brackets are creating a list of column names to subset.
# Show only the first 6 rows
df[0:6][["Registration Mark","Registered Owner"]]
# Out:
#   Registration Mark                                   Registered Owner
# 0            EI-ABI                   AER LINGUS CHARITABLE FOUNDATION
# 1            EI-ABS                                       BENNETT SEAN
# 2            EI-AEE  O'SULLIVAN, OWEN EUGENE PATRICK\nO'SULLIVAN AR...
# 3            EI-AEF                                     HALLIGAN JAMES
# 4            EI-AEH                                        KELLY DAVID
# 5            EI-AEI  McMORROW, FRANK JOSEPH\nMcLOUGHLIN, PATRICK JO...

# %%
# sort by Year of Manufacture (oldest-newest)
df.sort_values("Year of Manufacture", ascending=True)
# Out:
#      Registration Mark                 Aircraft producer     Aircraft Model  \
# 18              EI-ALP  BAE SYSTEMS (OPERATIONS) LIMITED     AVRO 643 CADET
# 0               EI-ABI      DE HAVILLAND AIRCRAFT CO LTD        DH84 DRAGON
# 854             EI-GRB                PIPER AIRCRAFT INC       PIPER J3F-65
# 112             EI-CES  TAYLORCRAFT AVIATION CORPORATION  TAYLORCRAFT BC-65
# 1207            EI-TIM                PIPER AIRCRAFT INC          PIPER J5A
# ...                ...                               ...                ...
# 1176            EI-SIM                  AIRBUS INDUSTRIE          A320-251N
# 1175            EI-SIL                  AIRBUS INDUSTRIE          A320-251N
# 1174            EI-SIJ                  AIRBUS INDUSTRIE          A320-251N
# 1250               NaN                               NaN                NaN
# 1251             Total                              1250                NaN
#
# ...

# %%
#Subset Rows based on Text data. List all rows with AIRBUS INDUSTRIE	as the Aircraft producer. There are 195 rows showing.
df[df["Aircraft producer"] == "AIRBUS INDUSTRIE"] # use double equal sign to filter Aircraft_producer which is AIRBUS INDUSTRIE (Airbus)
# Out:
#      Registration Mark Aircraft producer Aircraft Model        Category  \
# 144             EI-CPE  AIRBUS INDUSTRIE       A321-211  LAND AEROPLANE
# 145             EI-CPG  AIRBUS INDUSTRIE       A321-211  LAND AEROPLANE
# 146             EI-CPH  AIRBUS INDUSTRIE       A321-211  LAND AEROPLANE
# 156             EI-CVA  AIRBUS INDUSTRIE       A320-214  LAND AEROPLANE
# 157             EI-CVB  AIRBUS INDUSTRIE       A320-214  LAND AEROPLANE
# ...                ...               ...            ...             ...
# 1172            EI-SIH  AIRBUS INDUSTRIE      A320-251N  LAND AEROPLANE
# 1173            EI-SII  AIRBUS INDUSTRIE      A320-251N  LAND AEROPLANE
# 1174            EI-SIJ  AIRBUS INDUSTRIE      A320-251N  LAND AEROPLANE
# 1175            EI-SIL  AIRBUS INDUSTRIE      A320-251N  LAND AEROPLANE
# 1176            EI-SIM  AIRBUS INDUSTRIE      A320-251N  LAND AEROPLANE
#
#      Registration date  MTOW (KGs)  Year of Manufacture  \
# ...

# %%
#Subsetting based on multiple conditions. Lets look at the amount of Aircraft Registered to AerCap (Irelands leading Aircraft Lessor). There are two AerCap entities listed.
is_AERCAP = df["Registered Owner"].isin(["AERCAP IRELAND ASSET INVESTMENT 2 LIMITED", "AERCAP IRELAND LIMITED"]) #AerCap entity 1 + entity2
df[is_AERCAP] #We needed to use the isin method here
# Out:
#     Registration Mark   Aircraft producer    Aircraft Model        Category  \
# 328            EI-DTM    AIRBUS INDUSTRIE          A320-216  LAND AEROPLANE
# 329            EI-DTN    AIRBUS INDUSTRIE          A320-216  LAND AEROPLANE
# 330            EI-DTO    AIRBUS INDUSTRIE          A320-216  LAND AEROPLANE
# 705            EI-FNI  THE BOEING COMPANY    BOEING 777-2Q8  LAND AEROPLANE
# 771            EI-GES  THE BOEING COMPANY  BOEING 777-31HER  LAND AEROPLANE
# 772            EI-GET  THE BOEING COMPANY  BOEING 777-31HER  LAND AEROPLANE
# 775            EI-GFA  THE BOEING COMPANY  BOEING 777-31HER  LAND AEROPLANE
# 776            EI-GFB  THE BOEING COMPANY  BOEING 777-31HER  LAND AEROPLANE
#
#     Registration date  MTOW (KGs)  Year of Manufacture Aircraft Serial Number  \
# 328        29/04/2010     73500.0               2010.0                   4119
# 329        25/03/2010     73500.0               2010.0                   4143
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check for duplicates
df.drop_duplicates(subset="Registration Mark")
# There are no duplicates. The below still shows 1252 rows × 14 columns
# Out:
#      Registration Mark             Aircraft producer  \
# 0               EI-ABI  DE HAVILLAND AIRCRAFT CO LTD
# 1               EI-ABS       BOEING AIRPLANE COMPANY
# 2               EI-AEE           AUSTER AIRCRAFT LTD
# 3               EI-AEF       CESSNA AIRCRAFT COMPANY
# 4               EI-AEH         LUSCOMBE AIRCRAFT LTD
# ...                ...                           ...
# 1247           EJ-REVA    BEECH AIRCRAFT CORPORATION
# 1248           EJ-ROXY                BOMBARDIER INC
# 1249           EJ-VAIS      PILATUS AIRCRAFT LIMITED
# 1250               NaN                           NaN
# 1251             Total                          1250
#
#                  Aircraft Model        Category Registration date  MTOW (KGs)  \
# 0                   DH84 DRAGON  LAND AEROPLANE        12/08/1985      1792.0
# 1                         B75N1  LAND AEROPLANE        17/10/2019      1338.0
# 2                    AUSTER 5J1  LAND AEROPLANE        22/12/2009       839.0
# ...

# %% [markdown]
# No duplicates found. This is correct as each Aircrfat has its own unique Registration Number. **Two Aircraft can't have the same Registration.**

# %%
# Replace NaN with 0
df.fillna(0)
# Out:
#      Registration Mark             Aircraft producer  \
# 0               EI-ABI  DE HAVILLAND AIRCRAFT CO LTD
# 1               EI-ABS       BOEING AIRPLANE COMPANY
# 2               EI-AEE           AUSTER AIRCRAFT LTD
# 3               EI-AEF       CESSNA AIRCRAFT COMPANY
# 4               EI-AEH         LUSCOMBE AIRCRAFT LTD
# ...                ...                           ...
# 1247           EJ-REVA    BEECH AIRCRAFT CORPORATION
# 1248           EJ-ROXY                BOMBARDIER INC
# 1249           EJ-VAIS      PILATUS AIRCRAFT LIMITED
# 1250                 0                             0
# 1251             Total                          1250
#
#                  Aircraft Model        Category Registration date  MTOW (KGs)  \
# 0                   DH84 DRAGON  LAND AEROPLANE        12/08/1985      1792.0
# 1                         B75N1  LAND AEROPLANE        17/10/2019      1338.0
# 2                    AUSTER 5J1  LAND AEROPLANE        22/12/2009       839.0
# ...

# %%
# The aircraft with 1935 as the year of manufacture is the oldest Registered Aircraft in Ireland
df["Year of Manufacture"].min()
# Out:
# 1935.0

# %%
# What Aircraft is this?
df.sort_values("Year of Manufacture", ascending=True) # sort by Year of Manufacture (oldest-newest). The first line item EI-ALP
# Out:
#      Registration Mark                 Aircraft producer     Aircraft Model  \
# 18              EI-ALP  BAE SYSTEMS (OPERATIONS) LIMITED     AVRO 643 CADET
# 0               EI-ABI      DE HAVILLAND AIRCRAFT CO LTD        DH84 DRAGON
# 854             EI-GRB                PIPER AIRCRAFT INC       PIPER J3F-65
# 112             EI-CES  TAYLORCRAFT AVIATION CORPORATION  TAYLORCRAFT BC-65
# 1207            EI-TIM                PIPER AIRCRAFT INC          PIPER J5A
# ...                ...                               ...                ...
# 1176            EI-SIM                  AIRBUS INDUSTRIE          A320-251N
# 1175            EI-SIL                  AIRBUS INDUSTRIE          A320-251N
# 1174            EI-SIJ                  AIRBUS INDUSTRIE          A320-251N
# 1250               NaN                               NaN                NaN
# 1251             Total                              1250                NaN
#
# ...

# %%
# 2022 is the most recent year of manufacture
df["Year of Manufacture"].max()
# Out:
# 2022.0

# %%
# MTOW is the heaviest weight at which the aircraft has been shown to meet all the airworthiness requirements applicable to it.
df.sort_values("MTOW (KGs)", ascending=False)
# Out:
#      Registration Mark   Aircraft producer        Aircraft Model  \
# 1238            EI-XLM  THE BOEING COMPANY        BOEING 747-412
# 1234            EI-XLG  THE BOEING COMPANY        BOEING 747-446
# 1233            EI-XLF  THE BOEING COMPANY        BOEING 747-446
# 1230            EI-XLC  THE BOEING COMPANY        BOEING 747-446
# 1235            EI-XLH  THE BOEING COMPANY        BOEING 747-446
# ...                ...                 ...                   ...
# 1123            EI-PGN                 ITV             ITV BOXER
# 1126            EI-PGS   DUDEK PARAGLIDERS  DUDEK UNIVERSAL 25.5
# 1127            EI-PGT                 ITV             ITV BOXER
# 1250               NaN                 NaN                   NaN
# 1251             Total                1250                   NaN
#
#               Category Registration date  MTOW (KGs)  Year of Manufacture  \
# 1238    LAND AEROPLANE        04/11/2011    396893.0               2001.0
# ...

# %%
# 396893.0 KG is the heaviest weight at which the EI-XLM has been shown to meet all the airworthiness requirements applicable to it.
df["MTOW (KGs)"].max()
# Out:
# 396893.0

# %%
# Create a Column called Registration Year, taking the year from the Registration_date column
df["Registration Year"] = pd.DatetimeIndex(df["Registration date"]).year 
df.head()
# Out:
#   Registration Mark             Aircraft producer Aircraft Model  \
# 0            EI-ABI  DE HAVILLAND AIRCRAFT CO LTD    DH84 DRAGON
# 1            EI-ABS       BOEING AIRPLANE COMPANY          B75N1
# 2            EI-AEE           AUSTER AIRCRAFT LTD     AUSTER 5J1
# 3            EI-AEF       CESSNA AIRCRAFT COMPANY     CESSNA 120
# 4            EI-AEH         LUSCOMBE AIRCRAFT LTD    LUSCOMBE 8F
#
#          Category Registration date  MTOW (KGs)  Year of Manufacture  \
# 0  LAND AEROPLANE        12/08/1985      1792.0               1936.0
# 1  LAND AEROPLANE        17/10/2019      1338.0               1941.0
# 2  LAND AEROPLANE        22/12/2009       839.0               1946.0
# 3  LAND AEROPLANE        16/03/2011       658.0               1947.0
# 4  LAND AEROPLANE        07/01/2014       635.0               1945.0
#
#   Aircraft Serial Number  Mode S             Engine Manufacturer  \
# 0                   6105  4CA368                       BLACKBURN
# ...

# %% [markdown]
# ## **4. Analysis**
#
#
# *   Conditional statements, looping, groupby
# *   Define a custom function to create reusable code
# *   Use NumPy functions
# *   Dictionary or Lists
#
#
# ---

# %%
# From this listing, what is the earliest AC Registration Year
df["Registration Year"].min()
# Out:
# 1964.0

# %%
# From this listing, what is the most recent AC Registration Year
df["Registration Year"].max()
# Out:
# 2022.0

# %%
# From the different AC Categories, whats the average number of Engines per Aircraft
df[df["Category"] == "LAND AEROPLANE"]["No. of Engines"].mean()
# Out:
# 1.7963594994311718

# %%
# Balloon type Aircraft have no Engines!!
df[df["Category"] == "BALLOON"]["No. of Engines"].mean()
# Out:
# 0.0

# %%
# Similar to Balloons, Sailplane type Aircraft have no Engines
df[df["Category"] == "SAILPLANE"]["No. of Engines"].mean()
# Out:
# 0.0

# %%
# List the average number of Engines per Aircraft
df.groupby("Category")["No. of Engines"].mean()
# Out:
# Category
# AMPHIBIAN                     1.000000
# BALLOON                       0.000000
# GYROCOPTER                    1.000000
# HOMEBUILD / AMPHIBIAN         1.000000
# HOMEBUILD / GYROCOPTER        1.000000
# HOMEBUILD / LAND AEROPLANE    1.000000
# HOMEBUILD / MICROLIGHT        1.000000
# HOMEBUILD / SAILPLANE         1.000000
# LAND AEROPLANE                1.796359
# MICROLIGHT                    1.000000
# POWER PARAGLIDER              0.000000
# POWERED SAILPLANE             1.000000
# ROTORCRAFT                    1.488372
# SAILPLANE                     0.000000
# UNMANNED AIRCRAFT SYSTEM      2.000000
# Name: No. of Engines, dtype: float64

# %%
# Use max() to better show this data
df.groupby("Category")["No. of Engines"].max()
# Out:
# Category
# AMPHIBIAN                     1.0
# BALLOON                       0.0
# GYROCOPTER                    1.0
# HOMEBUILD / AMPHIBIAN         1.0
# HOMEBUILD / GYROCOPTER        1.0
# HOMEBUILD / LAND AEROPLANE    1.0
# HOMEBUILD / MICROLIGHT        1.0
# HOMEBUILD / SAILPLANE         1.0
# LAND AEROPLANE                4.0
# MICROLIGHT                    1.0
# POWER PARAGLIDER              0.0
# POWERED SAILPLANE             1.0
# ROTORCRAFT                    2.0
# SAILPLANE                     0.0
# UNMANNED AIRCRAFT SYSTEM      2.0
# Name: No. of Engines, dtype: float64

# %%
 # Use the agg method to better show this data # Make a graph of this data
 df.groupby("Category")["No. of Engines"].agg([min, max])
# Out:
#                             min  max
# Category
# AMPHIBIAN                   1.0  1.0
# BALLOON                     0.0  0.0
# GYROCOPTER                  1.0  1.0
# HOMEBUILD / AMPHIBIAN       1.0  1.0
# HOMEBUILD / GYROCOPTER      1.0  1.0
# HOMEBUILD / LAND AEROPLANE  1.0  1.0
# HOMEBUILD / MICROLIGHT      1.0  1.0
# HOMEBUILD / SAILPLANE       1.0  1.0
# LAND AEROPLANE              1.0  4.0
# MICROLIGHT                  1.0  1.0
# POWER PARAGLIDER            0.0  0.0
# POWERED SAILPLANE           1.0  1.0
# ROTORCRAFT                  1.0  2.0
# SAILPLANE                   0.0  0.0
# UNMANNED AIRCRAFT SYSTEM    2.0  2.0

# %%
max_engine_by_category = df.groupby("Category")["No. of Engines"].max()
print(max_engine_by_category)
# Out:
# Category
# AMPHIBIAN                     1.0
# BALLOON                       0.0
# GYROCOPTER                    1.0
# HOMEBUILD / AMPHIBIAN         1.0
# HOMEBUILD / GYROCOPTER        1.0
# HOMEBUILD / LAND AEROPLANE    1.0
# HOMEBUILD / MICROLIGHT        1.0
# HOMEBUILD / SAILPLANE         1.0
# LAND AEROPLANE                4.0
# MICROLIGHT                    1.0
# POWER PARAGLIDER              0.0
# POWERED SAILPLANE             1.0
# ROTORCRAFT                    2.0
# SAILPLANE                     0.0
# UNMANNED AIRCRAFT SYSTEM      2.0
# Name: No. of Engines, dtype: float64

# %%
# Conditional statement 1 - For any AC Manufactured in 2022, in a new column "Manufactured This Year?" put True.
df["Manufactured This Year?"] = df["Year of Manufacture"].apply(lambda x: 'True' if x == 2022 else False)
df
# Out:
#      Registration Mark             Aircraft producer  \
# 0               EI-ABI  DE HAVILLAND AIRCRAFT CO LTD
# 1               EI-ABS       BOEING AIRPLANE COMPANY
# 2               EI-AEE           AUSTER AIRCRAFT LTD
# 3               EI-AEF       CESSNA AIRCRAFT COMPANY
# 4               EI-AEH         LUSCOMBE AIRCRAFT LTD
# ...                ...                           ...
# 1247           EJ-REVA    BEECH AIRCRAFT CORPORATION
# 1248           EJ-ROXY                BOMBARDIER INC
# 1249           EJ-VAIS      PILATUS AIRCRAFT LIMITED
# 1250               NaN                           NaN
# 1251             Total                          1250
#
#                  Aircraft Model        Category Registration date  MTOW (KGs)  \
# 0                   DH84 DRAGON  LAND AEROPLANE        12/08/1985      1792.0
# 1                         B75N1  LAND AEROPLANE        17/10/2019      1338.0
# 2                    AUSTER 5J1  LAND AEROPLANE        22/12/2009       839.0
# ...

# %%
# Check results. Double check Year of Manufacture is 2022. They are.
df[df["Manufactured This Year?"] == "True"]
# Out:
#      Registration Mark            Aircraft producer Aircraft Model  \
# 495             EI-EJW  LEONARDO S.p.A. HELICOPTERS        AW109SP
# 958             EI-HAR            COMCO IKARUS GMBH    IKARUS C42C
# 1174            EI-SIJ             AIRBUS INDUSTRIE      A320-251N
# 1175            EI-SIL             AIRBUS INDUSTRIE      A320-251N
# 1176            EI-SIM             AIRBUS INDUSTRIE      A320-251N
# 1227            EI-XHA           AIRBUS HELICOPTERS      AS 350 B3
#
#             Category Registration date  MTOW (KGs)  Year of Manufacture  \
# 495       ROTORCRAFT        24/03/2022      3175.0               2022.0
# 958       MICROLIGHT        10/03/2022       472.5               2022.0
# 1174  LAND AEROPLANE        08/02/2022     77000.0               2022.0
# 1175  LAND AEROPLANE        16/03/2022     77000.0               2022.0
# 1176  LAND AEROPLANE        31/03/2022     77000.0               2022.0
# ...

# %%
# Double Check.b
df[df["Year of Manufacture"] == 2022]
# Out:
#      Registration Mark            Aircraft producer Aircraft Model  \
# 495             EI-EJW  LEONARDO S.p.A. HELICOPTERS        AW109SP
# 958             EI-HAR            COMCO IKARUS GMBH    IKARUS C42C
# 1174            EI-SIJ             AIRBUS INDUSTRIE      A320-251N
# 1175            EI-SIL             AIRBUS INDUSTRIE      A320-251N
# 1176            EI-SIM             AIRBUS INDUSTRIE      A320-251N
# 1227            EI-XHA           AIRBUS HELICOPTERS      AS 350 B3
#
#             Category Registration date  MTOW (KGs)  Year of Manufacture  \
# 495       ROTORCRAFT        24/03/2022      3175.0               2022.0
# 958       MICROLIGHT        10/03/2022       472.5               2022.0
# 1174  LAND AEROPLANE        08/02/2022     77000.0               2022.0
# 1175  LAND AEROPLANE        16/03/2022     77000.0               2022.0
# 1176  LAND AEROPLANE        31/03/2022     77000.0               2022.0
# ...

# %%
#create new row using a dictionary {key:value}
new_row = {"Registration Mark":"T-123", "Aircraft producer":"TEST COMPANY", "Aircraft Model":"TEST 123", "Category": "TEST CATEGORY", "Registration date": "15/04/2022", "MTOW (KGs)":"0", "Year of Manufacture":"2022", "Mode S":"T123","Engine Manufacturer":"TEST", "Engine Model":"T12-34", "No. of Engines":"0", "Registered Owner":"ROSIE KEOGH", "Address":"DUBLIN", "Registration Year": "2022"}

# %%
#looping on the new_row
for key, value in new_row.items(): 
  print("The " + key + " is: " + str(value))
# Out:
# The Registration Mark is: T-123
# The Aircraft producer is: TEST COMPANY
# The Aircraft Model is: TEST 123
# The Category is: TEST CATEGORY
# The Registration date is: 15/04/2022
# The MTOW (KGs) is: 0
# The Year of Manufacture is: 2022
# The Mode S is: T123
# The Engine Manufacturer is: TEST
# The Engine Model is: T12-34
# The No. of Engines is: 0
# The Registered Owner is: ROSIE KEOGH
# The Address is: DUBLIN
# The Registration Year is: 2022

# %%
# what is the value in the Registration_Mark?
new_row["Registration Mark"]
# Out:
# 'T-123'

# %%
# Create mod_df and print to see if it contains the new row added (new_row). It does. TJhere are now 1253 rows.
mod_df = df.append({"Registration Mark":"T-123", "Aircraft producer":"TEST COMPANY", "Aircraft Model":"TEST 123", "Category": "TEST CATEGORY", "Registration date": "15/04/2022", "MTOW (KGs)":"0", "Year of Manufacture":"2022", "Mode S":"T123","Engine Manufacturer":"TEST", "Engine Model":"T12-34", "No. of Engines":"0", "Registered Owner":"ROSIE KEOGH", "Address":"DUBLIN", "Registration Year": "2022"}, ignore_index=True)
mod_df
# Out:
#      Registration Mark             Aircraft producer  \
# 0               EI-ABI  DE HAVILLAND AIRCRAFT CO LTD
# 1               EI-ABS       BOEING AIRPLANE COMPANY
# 2               EI-AEE           AUSTER AIRCRAFT LTD
# 3               EI-AEF       CESSNA AIRCRAFT COMPANY
# 4               EI-AEH         LUSCOMBE AIRCRAFT LTD
# ...                ...                           ...
# 1248           EJ-ROXY                BOMBARDIER INC
# 1249           EJ-VAIS      PILATUS AIRCRAFT LIMITED
# 1250               NaN                           NaN
# 1251             Total                          1250
# 1252             T-123                  TEST COMPANY
#
#                  Aircraft Model        Category Registration date MTOW (KGs)  \
# 0                   DH84 DRAGON  LAND AEROPLANE        12/08/1985     1792.0
# 1                         B75N1  LAND AEROPLANE        17/10/2019     1338.0
# 2                    AUSTER 5J1  LAND AEROPLANE        22/12/2009      839.0
# ...

# %%
df_array = df.values # covert DataFrame to a NumPy Array

# %%
df.to_numpy()
# Out:
# array([['EI-ABI', 'DE HAVILLAND AIRCRAFT CO LTD', 'DH84 DRAGON', ...,
#         'DUBLIN AIRPORT, CO. DUBLIN, ', 1985.0, False],
#        ['EI-ABS', 'BOEING AIRPLANE COMPANY', 'B75N1', ...,
#         '120 CHURCHTOWN ROAD LOWER, CHURCHTOWN, DUBLIN, 14, IRELAND',
#         2019.0, False],
#        ['EI-AEE', 'AUSTER AIRCRAFT LTD', 'AUSTER 5J1', ...,
#         'GLENARD, CROSTHWAITE PARK, DUN LAOGHAIRE, CO DUBLIN, IRELAND\nGLENARD, CROSTHWAITE PARK, DUN LAOGHAIRE, CO.DUBLIN, IRELAND',
#         2009.0, False],
#        ...,
#        ['EJ-VAIS', 'PILATUS AIRCRAFT LIMITED', 'PILATUS PC-12/47E', ...,
#         'PALMERSTON HOUSE, DENZILLE LANE, DUBLIN 2, ', 2021.0, False],
#        [nan, nan, nan, ..., nan, nan, False],
#        ['Total', 1250, nan, ..., nan, nan, False]], dtype=object)

# %%
# Out:
# ()

# %% [markdown]
# ## **5. Visualisation**
#
#
#
# *   Generate at least two charts using Matplotlib or Seaborn
#
#
# ---

# %%
# Chart 1 using Matplotlib
# Only Land Aeroplanes have 4 Enginer per Aircraft. Balloon / Power Paraglider / Sailplane don't have any Engines.
max_engine_by_category.plot(kind="bar", title = "Max No. of Engine per AC Category")
plt.ylabel("No of Engines per A/C")
plt.xlabel("A/C Category")
plt.show()

# %%
# Chart 2a using Matplotlib
# Show amount of AC Manufactured per year
df["Year of Manufacture"].hist()
plt.title("Count of AC Manufactured per Year")
plt.ylabel("Count")
plt.xlabel("Year")
plt.show()

# %%
# Chart 2b using Matplotlib
# change amount of bins
df["Year of Manufacture"].hist(bins=5)
plt.title("Count of AC Manufactured per Year")
plt.ylabel("Count")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ## **6. Insights**
#
#
#
# *   Derive five valuable insights from the analysis - **TO ACTION**
# *   Justify your insights with reference to the charts or analysis - **TO ACTION**
#
#
#
# ---

# %% [markdown]
# ## **7. Machine Learning**
#
#
#
# *   Describe what kind of prediction you could perform in future using machine learning and/or deep learning. - **TO ACTION**
# *   Would you use classification or regression methods? - **TO ACTION**
#
#
#
# ---
